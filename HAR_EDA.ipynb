# %% [markdown]
# # Importing the data

# %% [markdown]
# ## Obtaining the Features

# %%
# importing the libraries
import numpy as np
import pandas as pd

# get the features from the file features.txt and adding them a list named features
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

#mapping the labels 
y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
#printing a sample row
train.sample()
# Out:
# F:\anaconda\lib\site-packages\pandas\io\parsers.py:702: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 4192           0.265209          -0.022586          -0.133726
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 4192         -0.987506         -0.952209          -0.94058         -0.989062
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 4192         -0.952447         -0.946195         -0.933179  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 4192                    -0.001946                             -0.309115
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 4192                          0.323794                              0.503377
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 4192             -0.620887               0.32086              0.156595
#
#       subject  Activity  ActivityName
# 4192       21         5      STANDING
#
# [1 rows x 564 columns]

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# mapping the labels
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
#printing a sample row
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 2635           0.284841          -0.019201          -0.107611
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 2635         -0.972128         -0.995757         -0.991906         -0.972685
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 2635          -0.99466         -0.992572         -0.912239  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 2635                     0.205729                             -0.211422
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 2635                           0.39531                             -0.229736
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 2635               0.53998             -0.488183             -0.517488
#
#       subject  Activity  ActivityName
# 2635       24         6        LAYING
#
# [1 rows x 564 columns]

# %%
#checking the train and test shape
print(train.shape)
print(test.shape)
# Out:
# (7352, 564)
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Checking for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## Checking for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# _Observation_:
#
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# _Observation_:
# > Our data is well balanced (almost)

# %% [markdown]
# ## Changing feature names

# %%
columns = train.columns

# Removing '()','-'and',' from feature name names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ## Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# F:\anaconda\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  __ Observations__:
# >   *  If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# >   * If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# >   * If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# >   * We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ## Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# >   * If angleX,gravityMean > 0 then Activity is Laying.
# >   * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[5,20,50])
# Out:
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.460s...
# [t-SNE] Computed neighbors for 7352 samples in 82.325s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.109s
# [t-SNE] Iteration 50: error = 114.0743561, gradient norm = 0.0193896 (50 iterations in 10.042s)
# [t-SNE] Iteration 100: error = 97.6092606, gradient norm = 0.0154883 (50 iterations in 5.965s)
# [t-SNE] Iteration 150: error = 93.1947479, gradient norm = 0.0098864 (50 iterations in 4.841s)
# [t-SNE] Iteration 200: error = 91.2079697, gradient norm = 0.0069485 (50 iterations in 4.871s)
# [t-SNE] Iteration 250: error = 90.0364990, gradient norm = 0.0073410 (50 iterations in 5.044s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.036499
# [t-SNE] Iteration 300: error = 3.5654881, gradient norm = 0.0014524 (50 iterations in 4.726s)
# [t-SNE] Iteration 350: error = 2.8090768, gradient norm = 0.0007478 (50 iterations in 4.702s)
# [t-SNE] Iteration 400: error = 2.4300237, gradient norm = 0.0005212 (50 iterations in 4.760s)
# [t-SNE] Iteration 450: error = 2.2133152, gradient norm = 0.0004085 (50 iterations in 4.784s)
# [t-SNE] Iteration 500: error = 2.0688865, gradient norm = 0.0003346 (50 iterations in 4.841s)
# [t-SNE] Iteration 550: error = 1.9641563, gradient norm = 0.0002831 (50 iterations in 4.732s)
# [t-SNE] Iteration 600: error = 1.8833206, gradient norm = 0.0002450 (50 iterations in 4.910s)
# [t-SNE] Iteration 650: error = 1.8182735, gradient norm = 0.0002205 (50 iterations in 4.912s)
# [t-SNE] Iteration 700: error = 1.7646055, gradient norm = 0.0001997 (50 iterations in 4.900s)
# [t-SNE] Iteration 750: error = 1.7193580, gradient norm = 0.0001788 (50 iterations in 4.907s)
# [t-SNE] Iteration 800: error = 1.6803904, gradient norm = 0.0001663 (50 iterations in 4.942s)
# [t-SNE] Iteration 850: error = 1.6465791, gradient norm = 0.0001542 (50 iterations in 4.891s)
# [t-SNE] Iteration 900: error = 1.6169324, gradient norm = 0.0001445 (50 iterations in 4.922s)
# [t-SNE] Iteration 950: error = 1.5909122, gradient norm = 0.0001340 (50 iterations in 4.917s)
# [t-SNE] Iteration 1000: error = 1.5677058, gradient norm = 0.0001252 (50 iterations in 4.927s)
# [t-SNE] KL divergence after 1000 iterations: 1.567706
# Done..
# Creating plot for this t-sne visualization..
# F:\anaconda\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.467s...
# [t-SNE] Computed neighbors for 7352 samples in 85.828s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.354s
# [t-SNE] Iteration 50: error = 96.9497528, gradient norm = 0.0226600 (50 iterations in 8.393s)
# [t-SNE] Iteration 100: error = 83.6178513, gradient norm = 0.0061592 (50 iterations in 6.280s)
# [t-SNE] Iteration 150: error = 81.7571487, gradient norm = 0.0041768 (50 iterations in 6.206s)
# [t-SNE] Iteration 200: error = 81.0674133, gradient norm = 0.0023907 (50 iterations in 6.463s)
# [t-SNE] Iteration 250: error = 80.6956940, gradient norm = 0.0025593 (50 iterations in 6.282s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.695694
# [t-SNE] Iteration 300: error = 2.6934471, gradient norm = 0.0012981 (50 iterations in 5.791s)
# [t-SNE] Iteration 350: error = 2.1607196, gradient norm = 0.0005737 (50 iterations in 5.343s)
# [t-SNE] Iteration 400: error = 1.9119328, gradient norm = 0.0003459 (50 iterations in 5.432s)
# [t-SNE] Iteration 450: error = 1.7659968, gradient norm = 0.0002486 (50 iterations in 5.570s)
# [t-SNE] Iteration 500: error = 1.6720891, gradient norm = 0.0001939 (50 iterations in 5.461s)
# [t-SNE] Iteration 550: error = 1.6079552, gradient norm = 0.0001574 (50 iterations in 5.542s)
# [t-SNE] Iteration 600: error = 1.5616815, gradient norm = 0.0001358 (50 iterations in 5.534s)
# [t-SNE] Iteration 650: error = 1.5265896, gradient norm = 0.0001196 (50 iterations in 5.520s)
# [t-SNE] Iteration 700: error = 1.4992456, gradient norm = 0.0001054 (50 iterations in 5.512s)
# [t-SNE] Iteration 750: error = 1.4773461, gradient norm = 0.0000991 (50 iterations in 5.647s)
# [t-SNE] Iteration 800: error = 1.4595350, gradient norm = 0.0000916 (50 iterations in 5.520s)
# [t-SNE] Iteration 850: error = 1.4450729, gradient norm = 0.0000853 (50 iterations in 5.580s)
# [t-SNE] Iteration 900: error = 1.4328986, gradient norm = 0.0000781 (50 iterations in 5.606s)
# [t-SNE] Iteration 950: error = 1.4225330, gradient norm = 0.0000744 (50 iterations in 5.606s)
# [t-SNE] Iteration 1000: error = 1.4136455, gradient norm = 0.0000695 (50 iterations in 5.644s)
# [t-SNE] KL divergence after 1000 iterations: 1.413646
# Done..
# Creating plot for this t-sne visualization..
# F:\anaconda\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.454s...
# [t-SNE] Computed neighbors for 7352 samples in 86.619s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.945s
# [t-SNE] Iteration 50: error = 86.7660522, gradient norm = 0.0165457 (50 iterations in 11.431s)
# [t-SNE] Iteration 100: error = 75.5699310, gradient norm = 0.0058734 (50 iterations in 9.647s)
# [t-SNE] Iteration 150: error = 74.5824509, gradient norm = 0.0020349 (50 iterations in 7.954s)
# [t-SNE] Iteration 200: error = 74.2263870, gradient norm = 0.0015076 (50 iterations in 7.686s)
# [t-SNE] Iteration 250: error = 74.0519257, gradient norm = 0.0011448 (50 iterations in 7.800s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.051926
# [t-SNE] Iteration 300: error = 2.1573133, gradient norm = 0.0011802 (50 iterations in 7.011s)
# [t-SNE] Iteration 350: error = 1.7592270, gradient norm = 0.0004896 (50 iterations in 6.828s)
# [t-SNE] Iteration 400: error = 1.5885197, gradient norm = 0.0002852 (50 iterations in 7.046s)
# [t-SNE] Iteration 450: error = 1.4942176, gradient norm = 0.0001912 (50 iterations in 6.952s)
# [t-SNE] Iteration 500: error = 1.4338111, gradient norm = 0.0001423 (50 iterations in 6.787s)
# [t-SNE] Iteration 550: error = 1.3924291, gradient norm = 0.0001127 (50 iterations in 7.006s)
# [t-SNE] Iteration 600: error = 1.3630608, gradient norm = 0.0000950 (50 iterations in 6.958s)
# [t-SNE] Iteration 650: error = 1.3419875, gradient norm = 0.0000829 (50 iterations in 6.887s)
# [t-SNE] Iteration 700: error = 1.3264910, gradient norm = 0.0000733 (50 iterations in 6.846s)
# [t-SNE] Iteration 750: error = 1.3144733, gradient norm = 0.0000691 (50 iterations in 7.088s)
# [t-SNE] Iteration 800: error = 1.3051355, gradient norm = 0.0000645 (50 iterations in 7.149s)
# [t-SNE] Iteration 850: error = 1.2977713, gradient norm = 0.0000638 (50 iterations in 6.924s)
# [t-SNE] Iteration 900: error = 1.2921185, gradient norm = 0.0000578 (50 iterations in 6.772s)
# [t-SNE] Iteration 950: error = 1.2876853, gradient norm = 0.0000577 (50 iterations in 7.079s)
# [t-SNE] Iteration 1000: error = 1.2841569, gradient norm = 0.0000544 (50 iterations in 6.993s)
# [t-SNE] KL divergence after 1000 iterations: 1.284157
# Done..
# Creating plot for this t-sne visualization..
# F:\anaconda\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# __ Observations__:
#
# > Applyting t-sne shows that we can well separate the datapoint i.e. our model can
#   will be able to classify but there will be problem in separating standing and sitting
#     as the points are overlapping
